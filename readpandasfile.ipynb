# %%
import pandas as pd

# %% [markdown]
# ## Read CSV files

# %%
pd.read_csv(r"C:\Users\hp\Downloads\assignment_python.csv")
# Out:
#        IDCUSTOMER GENDER       CITY COUNTRY  FIRST_DEPOSIT_AMOUNT  \
# 0         5075649      M     ankara  Turkey                 100.0
# 1         5176235      M     elazığ  Turkey                 400.0
# 2         5249140      M      izmir  Turkey                 200.0
# 3         5300998      M    Üsküdar  Turkey                 100.0
# 4         5371454      M    sakarya  Turkey                 880.0
# ...           ...    ...        ...     ...                   ...
# 22060   147844121      M   İstanbul  Turkey                  50.0
# 22061   147844491      M  Eskişehir  Turkey                  50.0
# 22062   147846481      M        Van  Turkey                 100.0
# 22063   147843561      M    Antalya  Turkey                 200.0
# 22064   147844971      M   İstanbul  Turkey                 150.0
#
#       REGISTRATION_DATE DEPOSIT_DATE
# 0            2009-01-10   2022-06-05
# 1            2009-03-01   2022-02-11
# 2            2009-04-06   2022-05-02
# ...

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\assignment_python.csv")
df
# Out:
#        IDCUSTOMER GENDER       CITY COUNTRY  FIRST_DEPOSIT_AMOUNT  \
# 0         5075649      M     ankara  Turkey                 100.0
# 1         5176235      M     elazığ  Turkey                 400.0
# 2         5249140      M      izmir  Turkey                 200.0
# 3         5300998      M    Üsküdar  Turkey                 100.0
# 4         5371454      M    sakarya  Turkey                 880.0
# ...           ...    ...        ...     ...                   ...
# 22060   147844121      M   İstanbul  Turkey                  50.0
# 22061   147844491      M  Eskişehir  Turkey                  50.0
# 22062   147846481      M        Van  Turkey                 100.0
# 22063   147843561      M    Antalya  Turkey                 200.0
# 22064   147844971      M   İstanbul  Turkey                 150.0
#
#       REGISTRATION_DATE DEPOSIT_DATE
# 0            2009-01-10   2022-06-05
# 1            2009-03-01   2022-02-11
# 2            2009-04-06   2022-05-02
# ...

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## Read Excel files

# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\hp\Downloads\customer_details.xlsx")
df
# Out:
#     Customer ID         customer_email       Customer Name      Segment  \
# 0      SC-20770    dinther@outlook.com  Stewart Carmichael    Corporate
# 1      RL-19615          msroth@me.com           Rob Lucas     Consumer
# 2      BS-11590      dbindel@gmail.com       Brendan Sweed    Corporate
# 3      TS-21610    geekgrl@comcast.net        Troy Staebel     Consumer
# 4      TW-21025       cremonini@me.com   Tamara Willingham  Home Office
# ..          ...                    ...                 ...          ...
# 429    PK-19075      dbindel@gmail.com           Pete Kriz     Consumer
# 430    JE-16165         tangsh@mac.com      Justin Ellison    Corporate
# 431    BD-11500  shaffei@sbcglobal.net     Bradley Drucker     Consumer
# 432    BF-11020         tangsh@mac.com   Barry Französisch    Corporate
# 433    BW-11110       atmarks@live.com        Bart Watters    Corporate
#
#            Country        City      State  Postal Code   Region State Code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     434 non-null    object
#  1   customer_email  423 non-null    object
#  2   Customer Name   434 non-null    object
#  3   Segment         434 non-null    object
#  4   Country         434 non-null    object
#  5   City            434 non-null    object
#  6   State           434 non-null    object
#  7   Postal Code     434 non-null    int64
#  8   Region          434 non-null    object
#  9   State Code      434 non-null    object
#  10  Domain Names    423 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 37.4+ KB

# %%
df.shape
# Out:
# (434, 11)

# %%
df.tail(5)
# Out:
#     Customer ID         customer_email      Customer Name    Segment  \
# 429    PK-19075      dbindel@gmail.com          Pete Kriz   Consumer
# 430    JE-16165         tangsh@mac.com     Justin Ellison  Corporate
# 431    BD-11500  shaffei@sbcglobal.net    Bradley Drucker   Consumer
# 432    BF-11020         tangsh@mac.com  Barry Französisch  Corporate
# 433    BW-11110       atmarks@live.com       Bart Watters  Corporate
#
#            Country       City      State  Postal Code   Region State Code  \
# 429  United States    Madison  Wisconsin        53711  Central         WI
# 430  United States   Franklin  Wisconsin        53132  Central         WI
# 431  United States  Green Bay  Wisconsin        54302  Central         WI
# 432  United States  Green Bay  Wisconsin        54302  Central         WI
# 433  United States  Milwaukee  Wisconsin        53209  Central         WI
#
#       Domain Names
# 429      gmail.com
# 430        mac.com
# 431  sbcglobal.net
# 432        mac.com
# ...

# %%
df['Customer ID']
# Out:
# 0      SC-20770
# 1      RL-19615
# 2      BS-11590
# 3      TS-21610
# 4      TW-21025
#          ...
# 429    PK-19075
# 430    JE-16165
# 431    BD-11500
# 432    BF-11020
# 433    BW-11110
# Name: Customer ID, Length: 434, dtype: object

# %%
df.loc[430]
# Out:
# Customer ID             JE-16165
# customer_email    tangsh@mac.com
# Customer Name     Justin Ellison
# Segment                Corporate
# Country            United States
# City                    Franklin
# State                  Wisconsin
# Postal Code                53132
# Region                   Central
# State Code                    WI
# Domain Names             mac.com
# Name: 430, dtype: object

# %%
df.iloc[430]
# Out:
# Customer ID             JE-16165
# customer_email    tangsh@mac.com
# Customer Name     Justin Ellison
# Segment                Corporate
# Country            United States
# City                    Franklin
# State                  Wisconsin
# Postal Code                53132
# Region                   Central
# State Code                    WI
# Domain Names             mac.com
# Name: 430, dtype: object
